# %% [markdown]
# # Task 18
# ## Practical Task 1

# %% [markdown]
# ### Read diabetes_dirty.csv into your jupyter Notebook

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer

# %%
# Import the dataset
df =pd.read_csv("diabetes_dirty.csv",)

# %% [markdown]
# ### Differentiate between the independent variables and the dependent variable, and assign them to variables X and Y.

# %%
# get idea of information (shape, columns, dtypes, info, head, and some basic visualisations colour coded by outcome 
df.shape
# Out:
# (442, 11)

# %%
df.columns
# Out:
# Index(['AGE', 'SEX', 'BMI', 'BP', 'S1', 'S2', 'S3', 'S4', 'S5', 'S6',
#        'PROGRESSION'],
#       dtype='object')

# %%
df.dtypes
# Out:
# AGE              int64
# SEX              int64
# BMI            float64
# BP             float64
# S1               int64
# S2             float64
# S3             float64
# S4             float64
# S5             float64
# S6               int64
# PROGRESSION      int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   AGE          442 non-null    int64
#  1   SEX          442 non-null    int64
#  2   BMI          442 non-null    float64
#  3   BP           442 non-null    float64
#  4   S1           442 non-null    int64
#  5   S2           442 non-null    float64
#  6   S3           442 non-null    float64
#  7   S4           442 non-null    float64
#  8   S5           442 non-null    float64
#  9   S6           442 non-null    int64
#  10  PROGRESSION  442 non-null    int64
# dtypes: float64(6), int64(5)
# memory usage: 38.1 KB

# %%
df.head()
# Out:
#    AGE  SEX   BMI     BP   S1     S2    S3   S4      S5  S6  PROGRESSION
# 0   59    2  32.1  101.0  157   93.2  38.0  4.0  4.8598  87          151
# 1   48    1  21.6   87.0  183  103.2  70.0  3.0  3.8918  69           75
# 2   72    2  30.5   93.0  156   93.6  41.0  4.0  4.6728  85          141
# 3   24    1  25.3   84.0  198  131.4  40.0  5.0  4.8903  89          206
# 4   50    1  23.0  101.0  192  125.4  52.0  4.0  4.2905  80          135

# %% [markdown]
# ### Independent Variables:
# * AGE
# * SEX
# * BMI
# * BP
# * S1
# * S2
# * S3
# * S4
# * S5
# * S6
#
#
# ### Dependent Variable:
# * PROGRESSION

# %%
X = df[['AGE', 'SEX', 'BMI', 'BP', 'S1', 'S2', 'S3', 'S4', 'S5', 'S6',]]
y = df[['PROGRESSION']]

# %% [markdown]
# ### Generate training and test sets comprising 80% and 20% of the data respectively

# %%
rseed = 42
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2,  random_state=rseed, shuffle=True,)

print ("Training data:",X_train.shape, y_train.shape)
print ("Test data:",X_test.shape, y_test.shape)
# Out:
# Training data: (353, 10) (353, 1)
# Test data: (89, 10) (89, 1)

# %% [markdown]
# ### Investigate the necessity for scaling or normalization of the data. Employ **MinMaxScaler** and **StandardScaler** if necessary. Fit these scalers on the training set and apply fitted scalars to transform both training and test sets accordingly.

# %%
#simple linear regression for each of the 10 independent variables

# %%
#0
# *'AGE'*, 'SEX', 'BMI', 'BP', 'S1', 'S2', 'S3', 'S4', 'S5', 'S6'

# Select and reshape data
x = df.iloc[:,0].values
y = df.iloc[:,10].values
y=y.reshape(-1, 1)
x=x.reshape(-1, 1)

#Create an empty linear regression model
a_model = LinearRegression()

# Create the model using fit(x,y)
a_model.fit(x,y)

# Use model to make a prediction
y_pred = a_model.predict(x)

# Plot model and data
plt.scatter(x,y,color = 'b')
plt.plot(x,a_model.predict(x),color = 'r')
plt.title('Age vs Progression')
plt.xlabel('Age')
plt.ylabel('Progression')
plt.show()

# %%
#1
# 'AGE', *'SEX'*, 'BMI', 'BP', 'S1', 'S2', 'S3', 'S4', 'S5', 'S6'

# Select and reshape data
x = df.iloc[:,1].values
y = df.iloc[:,10].values
y=y.reshape(-1, 1)
x=x.reshape(-1, 1)

#Create an empty linear regression model
s_model = LinearRegression()

# Create the model using fit(x,y)
s_model.fit(x,y)

# Use model to make a prediction
y_pred = s_model.predict(x)

# Plot model and data
plt.scatter(x,y,color = 'b')
plt.plot(x,s_model.predict(x),color = 'r')
plt.title('Sex vs Progression')
plt.xlabel('Sex')
plt.ylabel('Progression')
plt.show()

# %%
#2
# 'AGE', 'SEX', *'BMI'*, 'BP', 'S1', 'S2', 'S3', 'S4', 'S5', 'S6'

# Select and reshape data
x = df.iloc[:,2].values
y = df.iloc[:,10].values
y=y.reshape(-1, 1)
x=x.reshape(-1, 1)

#Create an empty linear regression model
b_model = LinearRegression()

# Create the model using fit(x,y)
b_model.fit(x,y)

# Use model to make a prediction
y_pred = b_model.predict(x)

# Plot model and data
plt.scatter(x,y,color = 'b')
plt.plot(x,b_model.predict(x),color = 'r')
plt.title('BMI vs Progression')
plt.xlabel('BMI')
plt.ylabel('Progression')
plt.show()

# %%
#3
# 'AGE', 'SEX', 'BMI', *'BP'*, 'S1', 'S2', 'S3', 'S4', 'S5', 'S6'

# Select and reshape data
x = df.iloc[:,3].values
y = df.iloc[:,10].values
y=y.reshape(-1, 1)
x=x.reshape(-1, 1)

#Create an empty linear regression model
bp_model = LinearRegression()

# Create the model using fit(x,y)
bp_model.fit(x,y)

# Use model to make a prediction
y_pred = bp_model.predict(x)

# Plot model and data
plt.scatter(x,y,color = 'b')
plt.plot(x,bp_model.predict(x),color = 'r')
plt.title('BP vs Progression')
plt.xlabel('BP')
plt.ylabel('Progression')
plt.show()

# %%
#4
# 'AGE', 'SEX', 'BMI', 'BP', *'S1'*, 'S2', 'S3', 'S4', 'S5', 'S6'

# Select and reshape data
x = df.iloc[:,4].values
y = df.iloc[:,10].values
y=y.reshape(-1, 1)
x=x.reshape(-1, 1)

#Create an empty linear regression model
s1_model = LinearRegression()

# Create the model using fit(x,y)
s1_model.fit(x,y)

# Use model to make a prediction
y_pred = s1_model.predict(x)

# Plot model and data
plt.scatter(x,y,color = 'b')
plt.plot(x,s1_model.predict(x),color = 'r')
plt.title('S1 vs Progression')
plt.xlabel('S1')
plt.ylabel('Progression')
plt.show()

# %%
#5
# 'AGE', 'SEX', 'BMI', 'BP', 'S1', *'S2'*, 'S3', 'S4', 'S5', 'S6'

# Select and reshape data
x = df.iloc[:,5].values
y = df.iloc[:,10].values
y=y.reshape(-1, 1)
x=x.reshape(-1, 1)

#Create an empty linear regression model
s2_model = LinearRegression()

# Create the model using fit(x,y)
s2_model.fit(x,y)

# Use model to make a prediction
y_pred = s2_model.predict(x)

# Plot model and data
plt.scatter(x,y,color = 'b')
plt.plot(x,s2_model.predict(x),color = 'r')
plt.title('S2 vs Progression')
plt.xlabel('S2')
plt.ylabel('Progression')
plt.show()

# %%
#6
# 'AGE', 'SEX', 'BMI', 'BP', 'S1', 'S2', *'S3'*, 'S4', 'S5', 'S6'

# Select and reshape data
x = df.iloc[:,6].values
y = df.iloc[:,10].values
y=y.reshape(-1, 1)
x=x.reshape(-1, 1)

#Create an empty linear regression model
s3_model = LinearRegression()

# Create the model using fit(x,y)
s3_model.fit(x,y)

# Use model to make a prediction
y_pred = s3_model.predict(x)

# Plot model and data
plt.scatter(x,y,color = 'b')
plt.plot(x,s3_model.predict(x),color = 'r')
plt.title('S3 vs Progression')
plt.xlabel('S3')
plt.ylabel('Progression')
plt.show()

# %%
#7
# 'AGE', 'SEX', 'BMI', 'BP', 'S1', 'S2', 'S3', '*S4'*, 'S5', 'S6'

# Select and reshape data
x = df.iloc[:,7].values
y = df.iloc[:,10].values
y=y.reshape(-1, 1)
x=x.reshape(-1, 1)

#Create an empty linear regression model
s4_model = LinearRegression()

# Create the model using fit(x,y)
s4_model.fit(x,y)

# Use model to make a prediction
y_pred = s4_model.predict(x)

# Plot model and data
plt.scatter(x,y,color = 'b')
plt.plot(x,s4_model.predict(x),color = 'r')
plt.title('S4 vs Progression')
plt.xlabel('S4')
plt.ylabel('Progression')
plt.show()

# %%
#8
# 'AGE', 'SEX', 'BMI', 'BP', 'S1', 'S2', 'S3', 'S4', *'S5'*, 'S6'

# Select and reshape data
x = df.iloc[:,8].values
y = df.iloc[:,10].values
y=y.reshape(-1, 1)
x=x.reshape(-1, 1)

#Create an empty linear regression model
s5_model = LinearRegression()

# Create the model using fit(x,y)
s5_model.fit(x,y)

# Use model to make a prediction
y_pred = s5_model.predict(x)

# Plot model and data
plt.scatter(x,y,color = 'b')
plt.plot(x,s5_model.predict(x),color = 'r')
plt.title('S5 vs Progression')
plt.xlabel('S5')
plt.ylabel('Progression')
plt.show()

# %%
#9
# 'AGE', 'SEX', 'BMI', 'BP', 'S1', 'S2', 'S3', 'S4', 'S5', *'S6'*

# Select and reshape data
x = df.iloc[:,9].values
y = df.iloc[:,10].values
y=y.reshape(-1, 1)
x=x.reshape(-1, 1)

#Create an empty linear regression model
s6_model = LinearRegression()

# Create the model using fit(x,y)
s6_model.fit(x,y)

# Use model to make a prediction
y_pred = s6_model.predict(x)

# Plot model and data
plt.scatter(x,y,color = 'b')
plt.plot(x,s6_model.predict(x),color = 'r')
plt.title('S6 vs Progression')
plt.xlabel('S6')
plt.ylabel('Progression')
plt.show()

# %%
print( 'Coefficients:'
    '\nAGE', a_model.coef_ , 
      '\nSEX', s_model.coef_ , 
      '\nBMI', b_model.coef_ ,
      '\nBP', bp_model.coef_ ,
      '\nS1', s1_model.coef_ ,
      '\nS2', s2_model.coef_ ,
      '\nS3', s3_model.coef_ ,
      '\nS4', s4_model.coef_ ,
      '\nS5', s5_model.coef_ ,
      '\nS6', s6_model.coef_ ,)
# Out:
# Coefficients:
# AGE [[1.10495671]]
# SEX [[6.64539007]]
# BMI [[10.23312787]]
# BP [[2.46073731]]
# S1 [[0.47230194]]
# S2 [[0.44120206]]
# S3 [[-2.35310142]]
# S4 [[25.71576493]]
# S5 [[83.51144243]]
# S6 [[2.56488713]]

# %%
sns.pairplot(data =df.drop('PROGRESSION', axis=1))

# %% [markdown]
# Standard scaler is good when data follows a normal/ gaussian distribution (bell curve)
# * Age
# * BP
# * S1
# * S3
#
# MinMaxScaler is better when there isnt normal/ gaussian distribution
# * Sex
# * BMI
# * S2
# * S4
# * S5
# * S6

# %%
ss = StandardScaler()
mms = MinMaxScaler()

ct = ColumnTransformer(
    [("ss1", StandardScaler(),['AGE', 'BP', 'S1', 'S3', ]),
     ("mms1", MinMaxScaler(),['SEX', 'BMI', 'S2', 'S4', 'S5', 'S6'])])

X_train = ct.fit_transform(X_train)
X_test = ct.transform(X_test)

# %%
### Generate a multiple linear regression model using the training set. Use all of the independent variables.

# %%
lm = LinearRegression()
model_m = lm.fit(X_train,y_train)

# %% [markdown]
# ### Print out the intercept and coefficients of the trained model

# %%
# Create line coordinates
X_line = np.empty(X_test.shape)
for i in range(X_test.shape[1]):
    X_line[:, i] = np.linspace(np.min(X_test[:,i]), np.max(X_test[:,i]), num=X_test.shape[0])
y_line = lm.predict(X_line)

print('Intercept: \n', lm.intercept_)
print('Coefficients: \n', lm.coef_)
# Out:
# Intercept:
#  [-65.88075476]
# Coefficients:
#  [[  1.75375799  16.82887167 -44.44885564   7.67697768 -23.06446772
#   135.63561351 162.87932677  72.03113268 191.18672297  13.3055384 ]]

# %% [markdown]
# ### Generate predictions for the test set.

# %%
predictions = lm.predict(X_test)
predictions[0:5]
# Out:
# array([[139.5475584 ],
#        [179.51720835],
#        [134.03875572],
#        [291.41702925],
#        [123.78965872]])

# %%
df.iloc[0]
# Out:
# AGE             59.0000
# SEX              2.0000
# BMI             32.1000
# BP             101.0000
# S1             157.0000
# S2              93.2000
# S3              38.0000
# S4               4.0000
# S5               4.8598
# S6              87.0000
# PROGRESSION    151.0000
# Name: 0, dtype: float64

# %% [markdown]
# ### Compute R-squared for your model on the test set

# %%
print ("R2 Score:", round (model_m.score(X_test, y_test), 4))
# Out:
# R2 Score: 0.4526

# %% [markdown]
# This score is closer to 0, which suggests that the model does not fit the observations very well
